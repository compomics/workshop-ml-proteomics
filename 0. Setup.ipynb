# %%
! conda env create -f environment.yml
# Out:
# ...
# Solving environment: ...working... done
#
# ...
#
# win_inet_pton-1.1.0  | 9 KB      |            |   0%
# win_inet_pton-1.1.0  | 9 KB      | ########## | 100%
# win_inet_pton-1.1.0  | 9 KB      | ########## | 100%
#
# keras-applications-1 | 30 KB     |            |   0%
# keras-applications-1 | 30 KB     | ########## | 100%
#
# reportlab-3.5.68     | 2.4 MB    |            |   0%
# reportlab-3.5.68     | 2.4 MB    |            |   1%
# reportlab-3.5.68     | 2.4 MB    | ###        |  31%
# reportlab-3.5.68     | 2.4 MB    | ######5    |  65%
# reportlab-3.5.68     | 2.4 MB    | ########## | 100%
# reportlab-3.5.68     | 2.4 MB    | ########## | 100%
#
# statsmodels-0.13.2   | 10.6 MB   |            |   0%
# statsmodels-0.13.2   | 10.6 MB   | 6          |   7%
# statsmodels-0.13.2   | 10.6 MB   | #7         |  17%
# statsmodels-0.13.2   | 10.6 MB   | ##8        |  28%
# statsmodels-0.13.2   | 10.6 MB   | ###8       |  39%
# statsmodels-0.13.2   | 10.6 MB   | ####9      |  49%
# ...
